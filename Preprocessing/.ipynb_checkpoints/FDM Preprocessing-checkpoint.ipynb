# %%
import os

# Set the working directory
os.chdir(r"C:\Users\Vishva\Desktop\Preprocessing")
# Out:
# Current Working Directory: C:\Users\Vishva\Desktop\Preprocessing

# %%
# Verify the current working directory
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: C:\Users\Vishva\Desktop\Preprocessing

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("Rail_Equipment_Accident_Incident_Data.csv")
# Out:
# C:\Users\Vishva\AppData\Local\Temp\ipykernel_14800\2440496537.py:1: DtypeWarning: Columns (26,27,46,47,50,59,61,62,63,64,65,66,67,68,69,71,118,119,123) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Rail_Equipment_Accident_Incident_Data.csv")

# %%
data.shape
# Out:
# (215849, 147)

# %%
# Calculate the threshold for 10% missing data
threshold = len(data) * 0.10

# Iterate through the columns and drop those with more than 10% missing data
for var in data.columns:
    missing_count = data[var].isnull().sum()
    missing_percentage = missing_count / len(data) * 100
    print(f"{var} - Missing: {missing_percentage:.2f}%")
    
    if missing_count > threshold:
        data.drop(columns=[var], inplace=True)
        print(f"Dropped column: {var}")
# Out:
# Reporting Railroad Code - Missing: 0.00%
# Reporting Railroad Name - Missing: 0.00%
# Report Year - Missing: 0.00%
# Accident Number - Missing: 0.00%
# PDF Link - Missing: 0.00%
# Accident Year - Missing: 0.00%
# Accident Month - Missing: 0.00%
# Other Railroad Code - Missing: 91.30%
# Dropped column: Other Railroad Code
# Other Railroad Name - Missing: 91.33%
# Dropped column: Other Railroad Name
# Other Accident Number - Missing: 91.30%
# Dropped column: Other Accident Number
# Other Accident Year - Missing: 91.31%
# Dropped column: Other Accident Year
# Other Accident Month - Missing: 91.31%
# Dropped column: Other Accident Month
# Maintenance Railroad Code - Missing: 0.00%
# Maintenance Railroad Name - Missing: 0.05%
# Maintenance Accident Number - Missing: 0.00%
# Maintenance Accident Year - Missing: 0.00%
# Maintenance Accident Month - Missing: 0.00%
# Grade Crossing ID - Missing: 94.84%
# Dropped column: Grade Crossing ID
# Day - Missing: 0.00%
# Date - Missing: 0.00%
# Time - Missing: 0.00%
# Accident Type Code - Missing: 0.00%
# Accident Type - Missing: 0.00%
# Hazmat Cars - Missing: 0.00%
# Hazmat Cars Damaged - Missing: 0.00%
# Hazmat Released Cars - Missing: 0.00%
# Persons Evacuated - Missing: 0.00%
# Subdivision - Missing: 86.70%
# Dropped column: Subdivision
# Division Code - Missing: 16.59%
# Dropped column: Division Code
# Division - Missing: 15.23%
# Dropped column: Division
# Station - Missing: 0.12%
# Milepost - Missing: 13.65%
# Dropped column: Milepost
# State Code - Missing: 0.00%
# State Abbreviation - Missing: 0.00%
# State Name - Missing: 0.00%
# County Code - Missing: 1.68%
# County Name - Missing: 1.68%
# District - Missing: 0.00%
# Temperature - Missing: 0.00%
# Visibility Code - Missing: 0.11%
# Visibility - Missing: 0.11%
# Weather Condition Code - Missing: 0.18%
# Weather Condition - Missing: 0.18%
# Track Type Code - Missing: 1.07%
# Track Type - Missing: 1.08%
# Track Name - Missing: 1.23%
# Track Class - Missing: 5.58%
# Track Density - Missing: 60.01%
# Dropped column: Track Density
# Train Direction Code - Missing: 9.91%
# Train Direction - Missing: 9.92%
# Equipment Type Code - Missing: 5.19%
# Equipment Type - Missing: 5.19%
# Equipment Attended - Missing: 12.27%
# Dropped column: Equipment Attended
# Train Number - Missing: 16.18%
# Dropped column: Train Number
# Train Speed - Missing: 0.00%
# Recorded Estimated Speed - Missing: 7.74%
# Maximum Speed - Missing: 0.00%
# Gross Tonnage - Missing: 0.00%
# Signalization Code - Missing: 86.70%
# Dropped column: Signalization Code
# Signalization - Missing: 86.70%
# Dropped column: Signalization
# Method of Operation Code - Missing: 14.41%
# Dropped column: Method of Operation Code
# Method of Operation - Missing: 86.70%
# Dropped column: Method of Operation
# Adjunct Code 1 - Missing: 91.32%
# Dropped column: Adjunct Code 1
# Adjunct Code Name 1 - Missing: 91.32%
# Dropped column: Adjunct Code Name 1
# Adjunct Code 2 - Missing: 99.01%
# Dropped column: Adjunct Code 2
# Adjunct Code Name 2 - Missing: 99.01%
# Dropped column: Adjunct Code Name 2
# Adjunct Code 3 - Missing: 99.72%
# Dropped column: Adjunct Code 3
# Adjunct Code Name 3 - Missing: 99.72%
# Dropped column: Adjunct Code Name 3
# Remote Control Locomotive Code - Missing: 74.84%
# Dropped column: Remote Control Locomotive Code
# Remote Control Locomotive - Missing: 74.84%
# Dropped column: Remote Control Locomotive
# First Car Initials - Missing: 5.66%
# First Car Number - Missing: 5.19%
# First Car Position - Missing: 6.19%
# First Car Loaded - Missing: 16.80%
# Dropped column: First Car Loaded
# Causing Car Initials - Missing: 88.12%
# Dropped column: Causing Car Initials
# Causing Car Number - Missing: 88.09%
# Dropped column: Causing Car Number
# Causing Car Position - Missing: 54.49%
# Dropped column: Causing Car Position
# Causing Car Loaded - Missing: 88.73%
# Dropped column: Causing Car Loaded
# Positive Alcohol Tests - Missing: 64.61%
# Dropped column: Positive Alcohol Tests
# Positive Drug Tests - Missing: 64.44%
# Dropped column: Positive Drug Tests
# Passengers Transported - Missing: 4.94%
# Head End Locomotives - Missing: 0.00%
# Mid Train Manual Locomotives - Missing: 0.00%
# Mid Train Remote Locomotives - Missing: 0.00%
# Rear End Manual Locomotives - Missing: 0.00%
# Rear End Remote Locomotives - Missing: 0.00%
# Derailed Head End Locomotives - Missing: 0.00%
# Derailed Mid Train Manual Locomotives - Missing: 0.00%
# Derailed Mid Train Remote Locomotives - Missing: 0.00%
# Derailed Rear End Manual Locomotives - Missing: 0.00%
# Derailed Rear End Remote Locomotives - Missing: 0.00%
# Loaded Freight Cars - Missing: 0.00%
# Loaded Passenger Cars - Missing: 0.00%
# Empty Freight Cars - Missing: 0.00%
# Empty Passenger Cars - Missing: 0.00%
# Cabooses - Missing: 0.00%
# Derailed Loaded Freight Cars - Missing: 0.00%
# Derailed Loaded Passenger Cars - Missing: 0.00%
# Derailed Empty Freight Cars - Missing: 0.00%
# Derailed Empty Passenger Cars - Missing: 0.00%
# Derailed Cabooses - Missing: 0.00%
# Equipment Damage Cost - Missing: 0.00%
# Track Damage Cost - Missing: 0.00%
# Total Damage Cost - Missing: 0.00%
# Primary Accident Cause Code - Missing: 0.00%
# Primary Accident Cause - Missing: 0.52%
# Contributing Accident Cause Code - Missing: 90.32%
# Dropped column: Contributing Accident Cause Code
# Contributing Accident Cause - Missing: 90.36%
# Dropped column: Contributing Accident Cause
# Accident Cause Code - Missing: 0.00%
# Accident Cause - Missing: 0.52%
# Engineers On Duty - Missing: 11.84%
# Dropped column: Engineers On Duty
# Firemen On Duty - Missing: 18.54%
# Dropped column: Firemen On Duty
# Conductors On Duty - Missing: 12.74%
# Dropped column: Conductors On Duty
# Brakemen On Duty - Missing: 15.65%
# Dropped column: Brakemen On Duty
# Hours Engineers On Duty - Missing: 21.26%
# Dropped column: Hours Engineers On Duty
# Minutes Engineers On Duty - Missing: 25.11%
# Dropped column: Minutes Engineers On Duty
# Hours Conductors On Duty - Missing: 23.60%
# Dropped column: Hours Conductors On Duty
# Minutes Conductors On Duty - Missing: 27.01%
# Dropped column: Minutes Conductors On Duty
# Special Study 1 - Missing: 86.61%
# Dropped column: Special Study 1
# Special Study 2 - Missing: 93.36%
# Dropped column: Special Study 2
# Latitude - Missing: 71.61%
# Dropped column: Latitude
# Longitude - Missing: 71.60%
# Dropped column: Longitude
# Joint Track Type - Missing: 0.25%
# Joint Track Class - Missing: 0.19%
# Class Code - Missing: 0.02%
# Joint CD - Missing: 0.00%
# Incident Key - Missing: 0.00%
# Report Key - Missing: 0.00%
# Reporting Railroad Company Grouping - Missing: 86.93%
# Dropped column: Reporting Railroad Company Grouping
# Reporting Railroad Class - Missing: 2.60%
# Reporting Railroad SMT Grouping - Missing: 11.30%
# Dropped column: Reporting Railroad SMT Grouping
# Reporting Parent Railroad Company Code - Missing: 0.00%
# Reporting Parent Railroad Company Name - Missing: 0.00%
# Reporting Railroad Holding Company - Missing: 0.00%
# Other Railroad Company Grouping - Missing: 97.64%
# Dropped column: Other Railroad Company Grouping
# Other Railroad Class - Missing: 92.47%
# Dropped column: Other Railroad Class
# Other Railroad SMT Grouping - Missing: 92.62%
# Dropped column: Other Railroad SMT Grouping
# Other Parent Railroad Company Code - Missing: 91.33%
# Dropped column: Other Parent Railroad Company Code
# Other Parent Railroad Company Name - Missing: 91.33%
# Dropped column: Other Parent Railroad Company Name
# Other Railroad Holding Company - Missing: 91.33%
# Dropped column: Other Railroad Holding Company
# Maintenance Railroad Company Grouping - Missing: 85.59%
# Dropped column: Maintenance Railroad Company Grouping
# Maintenance Railroad Class - Missing: 2.07%
# Maintenance Railroad SMT Grouping - Missing: 13.24%
# Dropped column: Maintenance Railroad SMT Grouping
# Maintenance Parent Railroad Company Code - Missing: 0.05%
# Maintenance Parent Railroad Company Name - Missing: 0.05%
# Maintenance Railroad Holding Company - Missing: 0.05%
# Class - Missing: 0.00%

# %%
data.shape
# Out:
# (215849, 91)

# %%
for var in data.columns:
    missing_count = data[var].isnull().sum()
    missing_percentage = missing_count / len(data) * 100
    print(f"{var} - Missing: {missing_percentage:.2f}%")
    
    if missing_count > threshold:
        print(f"Dropped column: {var}")
# Out:
# Reporting Railroad Code - Missing: 0.00%
# Reporting Railroad Name - Missing: 0.00%
# Report Year - Missing: 0.00%
# Accident Number - Missing: 0.00%
# PDF Link - Missing: 0.00%
# Accident Year - Missing: 0.00%
# Accident Month - Missing: 0.00%
# Maintenance Railroad Code - Missing: 0.00%
# Maintenance Railroad Name - Missing: 0.05%
# Maintenance Accident Number - Missing: 0.00%
# Maintenance Accident Year - Missing: 0.00%
# Maintenance Accident Month - Missing: 0.00%
# Day - Missing: 0.00%
# Date - Missing: 0.00%
# Time - Missing: 0.00%
# Accident Type Code - Missing: 0.00%
# Accident Type - Missing: 0.00%
# Hazmat Cars - Missing: 0.00%
# Hazmat Cars Damaged - Missing: 0.00%
# Hazmat Released Cars - Missing: 0.00%
# Persons Evacuated - Missing: 0.00%
# Station - Missing: 0.12%
# State Code - Missing: 0.00%
# State Abbreviation - Missing: 0.00%
# State Name - Missing: 0.00%
# County Code - Missing: 1.68%
# County Name - Missing: 1.68%
# District - Missing: 0.00%
# Temperature - Missing: 0.00%
# Visibility Code - Missing: 0.11%
# Visibility - Missing: 0.11%
# Weather Condition Code - Missing: 0.18%
# Weather Condition - Missing: 0.18%
# Track Type Code - Missing: 1.07%
# Track Type - Missing: 1.08%
# Track Name - Missing: 1.23%
# Track Class - Missing: 5.58%
# Train Direction Code - Missing: 9.91%
# Train Direction - Missing: 9.92%
# Equipment Type Code - Missing: 5.19%
# Equipment Type - Missing: 5.19%
# Train Speed - Missing: 0.00%
# Recorded Estimated Speed - Missing: 7.74%
# Maximum Speed - Missing: 0.00%
# Gross Tonnage - Missing: 0.00%
# First Car Initials - Missing: 5.66%
# First Car Number - Missing: 5.19%
# First Car Position - Missing: 6.19%
# Passengers Transported - Missing: 4.94%
# Head End Locomotives - Missing: 0.00%
# Mid Train Manual Locomotives - Missing: 0.00%
# Mid Train Remote Locomotives - Missing: 0.00%
# Rear End Manual Locomotives - Missing: 0.00%
# Rear End Remote Locomotives - Missing: 0.00%
# Derailed Head End Locomotives - Missing: 0.00%
# Derailed Mid Train Manual Locomotives - Missing: 0.00%
# Derailed Mid Train Remote Locomotives - Missing: 0.00%
# Derailed Rear End Manual Locomotives - Missing: 0.00%
# Derailed Rear End Remote Locomotives - Missing: 0.00%
# Loaded Freight Cars - Missing: 0.00%
# Loaded Passenger Cars - Missing: 0.00%
# Empty Freight Cars - Missing: 0.00%
# Empty Passenger Cars - Missing: 0.00%
# Cabooses - Missing: 0.00%
# Derailed Loaded Freight Cars - Missing: 0.00%
# Derailed Loaded Passenger Cars - Missing: 0.00%
# Derailed Empty Freight Cars - Missing: 0.00%
# Derailed Empty Passenger Cars - Missing: 0.00%
# Derailed Cabooses - Missing: 0.00%
# Equipment Damage Cost - Missing: 0.00%
# Track Damage Cost - Missing: 0.00%
# Total Damage Cost - Missing: 0.00%
# Primary Accident Cause Code - Missing: 0.00%
# Primary Accident Cause - Missing: 0.52%
# Accident Cause Code - Missing: 0.00%
# Accident Cause - Missing: 0.52%
# Joint Track Type - Missing: 0.25%
# Joint Track Class - Missing: 0.19%
# Class Code - Missing: 0.02%
# Joint CD - Missing: 0.00%
# Incident Key - Missing: 0.00%
# Report Key - Missing: 0.00%
# Reporting Railroad Class - Missing: 2.60%
# Reporting Parent Railroad Company Code - Missing: 0.00%
# Reporting Parent Railroad Company Name - Missing: 0.00%
# Reporting Railroad Holding Company - Missing: 0.00%
# Maintenance Railroad Class - Missing: 2.07%
# Maintenance Parent Railroad Company Code - Missing: 0.05%
# Maintenance Parent Railroad Company Name - Missing: 0.05%
# Maintenance Railroad Holding Company - Missing: 0.05%
# Class - Missing: 0.00%

# %%
data.shape
# Out:
# (215849, 91)

# %%
df = data

# %%
categorical_columns = df.select_dtypes(include=['object', 'category']).columns

# %%
df.isnull().sum()
# Out:
# Reporting Railroad Code                        1
# Reporting Railroad Name                        3
# Report Year                                    1
# Accident Number                                0
# PDF Link                                       5
#                                             ...
# Maintenance Railroad Class                  4463
# Maintenance Parent Railroad Company Code     100
# Maintenance Parent Railroad Company Name     100
# Maintenance Railroad Holding Company         100
# Class                                          0
# Length: 91, dtype: int64

# %%
for var in categorical_columns:
    mode_Value = df[var].mode()
    df.fillna({var: mode_Value}, inplace=True)

# %%
# Drop all rows that contain any null values
df = df.dropna(axis=0)

# %%
df.shape
# Out:
# (160727, 91)

# %%
df
# Out:
#        Reporting Railroad Code  \
# 0                         NICD
# 3                           IC
# 4                           IC
# 5                           NS
# 9                         BNSF
# ...                        ...
# 215844                     ALS
# 215845                      UP
# 215846                      UP
# 215847                      UP
# 215848                      IC
#
#                                   Reporting Railroad Name  Report Year  \
# 0       Northern Indiana Commuter Transportation District       2017.0
# 3                       Illinois Central Railroad Company       2007.0
# 4                       Illinois Central Railroad Company       2017.0
# 5                        Norfolk Southern Railway Company       2017.0
# 9                                    BNSF Railway Company       2017.0
# ...                                                   ...          ...
# 215844                           Alton & Southern Railway       2017.0
# 215845                     Union Pacific Railroad Company       2016.0
# 215846                     Union Pacific Railroad Company       2016.0
# 215847                     Union Pacific Railroad Company       2017.0
# 215848                  Illinois Central Railroad Company       2017.0
#
#        Accident Number                                           PDF Link  \
# 0             N1700013  https://safetydata.fra.dot.gov/Officeofsafety/...
# 3               543854  https://safetydata.fra.dot.gov/Officeofsafety/...
# 4               938223  https://safetydata.fra.dot.gov/Officeofsafety/...
# 5               127020  https://safetydata.fra.dot.gov/Officeofsafety/...
# 9            CH0417103  https://safetydata.fra.dot.gov/Officeofsafety/...
# ...                ...                                                ...
# 215844        20170621  https://safetydata.fra.dot.gov/Officeofsafety/...
# 215845       1216PR012  https://safetydata.fra.dot.gov/Officeofsafety/...
# 215846       1216PR012  https://safetydata.fra.dot.gov/Officeofsafety/...
# 215847       0217SL002  https://safetydata.fra.dot.gov/Officeofsafety/...
# 215848          924671  https://safetydata.fra.dot.gov/Officeofsafety/...
#
#         Accident Year  Accident Month Maintenance Railroad Code  \
# 0                17.0             6.0                      NIRC
# 3                 7.0             1.0                      CAEZ
# 4                17.0            10.0                        IC
# 5                17.0            10.0                        NS
# 9                17.0             4.0                      BNSF
# ...               ...             ...                       ...
# 215844           17.0             6.0                       ALS
# 215845           16.0            12.0                        UP
# 215846           16.0            12.0                        UP
# 215847           17.0             2.0                        UP
# 215848           17.0             6.0                      ZSTE
#
#                                 Maintenance Railroad Name  \
# 0       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...
# 3                                        Cargill Elevator
# 4                       Illinois Central Railroad Company
# 5                        Norfolk Southern Railway Company
# 9                                    BNSF Railway Company
# ...                                                   ...
# 215844                           Alton & Southern Railway
# 215845                     Union Pacific Railroad Company
# 215846                     Union Pacific Railroad Company
# 215847                     Union Pacific Railroad Company
# 215848                                   STEPHAN CHEMICAL
#
#        Maintenance Accident Number  ...           Report Key  \
# 0                        201707188  ...   NICDN1700013201706
# 3                         INDUSTRY  ...       IC543854200701
# 4                           938223  ...       IC938223201710
# 5                           127020  ...       NS127020201710
# 9                        CH0417103  ...  BNSFCH0417103201704
# ...                            ...  ...                  ...
# 215844                    20170621  ...    ALS20170621201706
# 215845                   1216PR012  ...    UP1216PR012201612
# 215846                   1216PR012  ...    UP1216PR012201612
# 215847                   0217SL002  ...    UP0217SL002201702
# 215848                    INDUSTRY  ...       IC924671201706
#
#         Reporting Railroad Class  Reporting Parent Railroad Company Code  \
# 0                        Class 3                                    NICD
# 3                        Class 1                                      CN
# 4                        Class 1                                      CN
# 5                        Class 1                                      NS
# 9                        Class 1                                    BNSF
# ...                          ...                                     ...
# 215844                   Class 1                                      UP
# 215845                   Class 1                                      UP
# 215846                   Class 1                                      UP
# 215847                   Class 1                                      UP
# 215848                   Class 1                                      CN
#
#                    Reporting Parent Railroad Company Name  \
# 0       Northern Indiana Commuter Transportation District
# 3                       Canadian National - North America
# 4                       Canadian National - North America
# 5                        Norfolk Southern Railway Company
# 9                                    BNSF Railway Company
# ...                                                   ...
# 215844                     Union Pacific Railroad Company
# 215845                     Union Pacific Railroad Company
# 215846                     Union Pacific Railroad Company
# 215847                     Union Pacific Railroad Company
# 215848                  Canadian National - North America
#
#        Reporting Railroad Holding Company  Maintenance Railroad Class  \
# 0                            Not Assigned                     Class 3
# 3       Canadian National - North America                     Class 3
# 4       Canadian National - North America                     Class 1
# 5        Norfolk Southern Railway Company                     Class 1
# 9                    BNSF Railway Company                     Class 1
# ...                                   ...                         ...
# 215844     Union Pacific Railroad Company                     Class 1
# 215845     Union Pacific Railroad Company                     Class 1
# 215846     Union Pacific Railroad Company                     Class 1
# 215847     Union Pacific Railroad Company                     Class 1
# 215848  Canadian National - North America                     Class 3
#
#        Maintenance Parent Railroad Company Code  \
# 0                                          NIRC
# 3                                          CAEZ
# 4                                            CN
# 5                                            NS
# 9                                          BNSF
# ...                                         ...
# 215844                                       UP
# 215845                                       UP
# 215846                                       UP
# 215847                                       UP
# 215848                                     ZSTE
#
#                  Maintenance Parent Railroad Company Name  \
# 0       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...
# 3                                        Cargill Elevator
# 4                       Canadian National - North America
# 5                        Norfolk Southern Railway Company
# 9                                    BNSF Railway Company
# ...                                                   ...
# 215844                     Union Pacific Railroad Company
# 215845                     Union Pacific Railroad Company
# 215846                     Union Pacific Railroad Company
# 215847                     Union Pacific Railroad Company
# 215848                                   STEPHAN CHEMICAL
#
#         Maintenance Railroad Holding Company  Class
# 0                               Not Assigned      0
# 3                               Not Assigned      0
# 4          Canadian National - North America      1
# 5           Norfolk Southern Railway Company      0
# 9                       BNSF Railway Company      0
# ...                                      ...    ...
# 215844        Union Pacific Railroad Company      0
# 215845        Union Pacific Railroad Company      0
# 215846        Union Pacific Railroad Company      0
# 215847        Union Pacific Railroad Company      0
# 215848                          Not Assigned      0
#
# [160727 rows x 91 columns]

# %%
df = data

# %%
# Identify numeric columns
numeric_columns = df.select_dtypes(include=['number']).columns

# Calculate the correlation matrix for numeric columns
correlation_matrix = df[numeric_columns].corr()

# Get absolute correlation values with the 'Class' column
correlation_with_class = correlation_matrix['Class'].abs()

# Filter out columns with correlation less than 0.1
columns_to_keep = correlation_with_class[correlation_with_class >= 0.1].index

df_filtered = df[columns_to_keep]

# Display the remaining columns and their correlations
print("Remaining columns:", df_filtered.columns)
print(correlation_with_class[columns_to_keep])
# Out:
# Remaining columns: Index(['Accident Type Code', 'Track Type Code', 'Train Speed', 'Maximum Speed',
#        'First Car Position', 'Derailed Head End Locomotives', 'Class'],
#       dtype='object')
# Accident Type Code               0.139331
# Track Type Code                  0.145953
# Train Speed                      0.257217
# Maximum Speed                    0.287453
# First Car Position               0.112304
# Derailed Head End Locomotives    0.132163
# Class                            1.000000
# Name: Class, dtype: float64

# %%
df.shape
# Out:
# (160727, 91)

# %%
from scipy.stats import chi2_contingency

# %%
categorical_columns = df.select_dtypes(include=['object', 'category']).columns

# %%
categorical_columns
# Out:
# Index(['Reporting Railroad Code', 'Reporting Railroad Name', 'Accident Number',
#        'PDF Link', 'Maintenance Railroad Code', 'Maintenance Railroad Name',
#        'Maintenance Accident Number', 'Date', 'Time', 'Accident Type',
#        'Persons Evacuated', 'Station', 'State Abbreviation', 'State Name',
#        'County Name', 'Visibility', 'Weather Condition', 'Track Type',
#        'Track Name', 'Track Class', 'Train Direction', 'Equipment Type Code',
#        'Equipment Type', 'Recorded Estimated Speed', 'Gross Tonnage',
#        'First Car Initials', 'First Car Number', 'Passengers Transported',
#        'Equipment Damage Cost', 'Track Damage Cost', 'Total Damage Cost',
#        'Primary Accident Cause Code', 'Primary Accident Cause',
#        'Accident Cause Code', 'Accident Cause', 'Joint Track Type',
#        'Joint Track Class', 'Class Code', 'Incident Key', 'Report Key',
#        'Reporting Railroad Class', 'Reporting Parent Railroad Company Code',
#        'Reporting Parent Railroad Company Name',
#        'Reporting Railroad Holding Company', 'Maintenance Railroad Class',
#        'Maintenance Parent Railroad Company Code',
#        'Maintenance Parent Railroad Company Name',
#        'Maintenance Railroad Holding Company'],
#       dtype='object')

# %%
for var in categorical_columns:
    cross_tab = pd.crosstab(index=df[var], columns=df["Class"])
    chi_sq_result = chi2_contingency(cross_tab,)
    p, x = chi_sq_result[1], "reject" if chi_sq_result[1] < 0.05 else "accept" 
    print(f"The p-value for {var} is {chi_sq_result[1]} and hence we {x} the null Hpothesis with {chi_sq_result[2]} degrees of freedom")
# Out:
# The p-value for Reporting Railroad Code is 0.0 and hence we reject the null Hpothesis with 872 degrees of freedom
# The p-value for Reporting Railroad Name is 0.0 and hence we reject the null Hpothesis with 869 degrees of freedom
# The p-value for Accident Number is 1.600356123631372e-183 and hence we reject the null Hpothesis with 129159 degrees of freedom
# The p-value for PDF Link is 1.861230232327502e-139 and hence we reject the null Hpothesis with 146702 degrees of freedom
# The p-value for Maintenance Railroad Code is 8.25166110154851e-78 and hence we reject the null Hpothesis with 2696 degrees of freedom
# The p-value for Maintenance Railroad Name is 1.0234819376315193e-78 and hence we reject the null Hpothesis with 2684 degrees of freedom
# The p-value for Maintenance Accident Number is 8.35462639696097e-271 and hence we reject the null Hpothesis with 124607 degrees of freedom
# The p-value for Date is 2.7320783733013424e-139 and hence we reject the null Hpothesis with 17427 degrees of freedom
# The p-value for Time is 0.0 and hence we reject the null Hpothesis with 1453 degrees of freedom
# The p-value for Accident Type is 0.0 and hence we reject the null Hpothesis with 12 degrees of freedom
# The p-value for Persons Evacuated is 1.9019835827897872e-131 and hence we reject the null Hpothesis with 223 degrees of freedom
# The p-value for Station is 0.0 and hence we reject the null Hpothesis with 19302 degrees of freedom
# The p-value for State Abbreviation is 1.2315905162988155e-64 and hence we reject the null Hpothesis with 49 degrees of freedom
# The p-value for State Name is 1.2315905162989558e-64 and hence we reject the null Hpothesis with 49 degrees of freedom
# The p-value for County Name is 0.0 and hence we reject the null Hpothesis with 1643 degrees of freedom
# The p-value for Visibility is 3.724481982977667e-153 and hence we reject the null Hpothesis with 3 degrees of freedom
# The p-value for Weather Condition is 8.384227131379719e-18 and hence we reject the null Hpothesis with 5 degrees of freedom
# The p-value for Track Type is 0.0 and hence we reject the null Hpothesis with 3 degrees of freedom
# The p-value for Track Name is 1.0 and hence we accept the null Hpothesis with 44926 degrees of freedom
# The p-value for Track Class is 0.0 and hence we reject the null Hpothesis with 17 degrees of freedom
# The p-value for Train Direction is 5.876044418413465e-09 and hence we reject the null Hpothesis with 3 degrees of freedom
# The p-value for Equipment Type Code is 0.0 and hence we reject the null Hpothesis with 22 degrees of freedom
# The p-value for Equipment Type is 0.0 and hence we reject the null Hpothesis with 13 degrees of freedom
# The p-value for Recorded Estimated Speed is 1.74329523756674e-67 and hence we reject the null Hpothesis with 7 degrees of freedom
# The p-value for Gross Tonnage is 3.228397277600585e-05 and hence we reject the null Hpothesis with 16090 degrees of freedom
# The p-value for First Car Initials is 0.0 and hence we reject the null Hpothesis with 3947 degrees of freedom
# The p-value for First Car Number is 1.0 and hence we accept the null Hpothesis with 107237 degrees of freedom
# The p-value for Passengers Transported is 0.0 and hence we reject the null Hpothesis with 1 degrees of freedom
# The p-value for Equipment Damage Cost is 3.0715081506602796e-151 and hence we reject the null Hpothesis with 39582 degrees of freedom
# The p-value for Track Damage Cost is 1.0 and hence we accept the null Hpothesis with 23864 degrees of freedom
# The p-value for Total Damage Cost is 0.0 and hence we reject the null Hpothesis with 51541 degrees of freedom
# The p-value for Primary Accident Cause Code is 0.0 and hence we reject the null Hpothesis with 381 degrees of freedom
# The p-value for Primary Accident Cause is 0.0 and hence we reject the null Hpothesis with 380 degrees of freedom
# The p-value for Accident Cause Code is 0.0 and hence we reject the null Hpothesis with 381 degrees of freedom
# The p-value for Accident Cause is 0.0 and hence we reject the null Hpothesis with 380 degrees of freedom
# The p-value for Joint Track Type is 0.0 and hence we reject the null Hpothesis with 3 degrees of freedom
# The p-value for Joint Track Class is 0.0 and hence we reject the null Hpothesis with 17 degrees of freedom
# The p-value for Class Code is 5.868466019795005e-132 and hence we reject the null Hpothesis with 13 degrees of freedom
# The p-value for Incident Key is 5.304966946092332e-171 and hence we reject the null Hpothesis with 145198 degrees of freedom
# The p-value for Report Key is 1.7780362531785566e-139 and hence we reject the null Hpothesis with 146701 degrees of freedom
# The p-value for Reporting Railroad Class is 0.9960958892595024 and hence we accept the null Hpothesis with 2 degrees of freedom
# The p-value for Reporting Parent Railroad Company Code is 0.0 and hence we reject the null Hpothesis with 712 degrees of freedom
# The p-value for Reporting Parent Railroad Company Name is 0.0 and hence we reject the null Hpothesis with 712 degrees of freedom
# The p-value for Reporting Railroad Holding Company is 9.388339250561453e-06 and hence we reject the null Hpothesis with 35 degrees of freedom
# The p-value for Maintenance Railroad Class is 3.02863751583661e-10 and hence we reject the null Hpothesis with 2 degrees of freedom
# The p-value for Maintenance Parent Railroad Company Code is 1.762915167589714e-49 and hence we reject the null Hpothesis with 2527 degrees of freedom
# The p-value for Maintenance Parent Railroad Company Name is 2.4867694324221545e-50 and hence we reject the null Hpothesis with 2517 degrees of freedom
# The p-value for Maintenance Railroad Holding Company is 5.843821348705268e-19 and hence we reject the null Hpothesis with 35 degrees of freedom

# %%
df.shape
# Out:
# (160727, 91)

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

def cramers_v(var1, var2):
    cross_tab = pd.crosstab(var1, var2)
    chi2 = chi2_contingency(cross_tab)[0]
    n = cross_tab.sum().sum()
    r, k = cross_tab.shape
    return np.sqrt(chi2 / (n * (min(r, k) - 1)))

# Calculate Cramér's V for each categorical column with 'Class'
categorical_columns = df.select_dtypes(include=['object', 'category']).columns
cramer_v_values = {}

for var in categorical_columns:
    cramer_v = cramers_v(df[var], df['Class'])
    cramer_v_values[var] = cramer_v

# Convert to a DataFrame for better visualization
cramer_v_df = pd.DataFrame(list(cramer_v_values.items()), columns=['Column', 'CramerV'])

# Filter strong correlations (e.g., > 0.3)
strong_categorical_correlations = cramer_v_df[cramer_v_df['CramerV'] > 0.2]

# Display strongly correlated categorical columns
print("Strongly correlated categorical columns:", strong_categorical_correlations)
# Out:
# Strongly correlated categorical columns:                          Column   CramerV
# 2               Accident Number  0.947816
# 3                      PDF Link  1.000000
# 6   Maintenance Accident Number  0.943181
# 7                          Date  0.374487
# 9                 Accident Type  0.507784
# 11                      Station  0.487318
# 18                   Track Name  0.460257
# 19                  Track Class  0.234898
# 24                Gross Tonnage  0.323464
# 25           First Car Initials  0.284975
# 26             First Car Number  0.690932
# 28        Equipment Damage Cost  0.543098
# 29            Track Damage Cost  0.367617
# 30            Total Damage Cost  0.640295
# 31  Primary Accident Cause Code  0.498805
# 32       Primary Accident Cause  0.498801
# 33          Accident Cause Code  0.498909
# 34               Accident Cause  0.498905
# 36            Joint Track Class  0.236294
# 38                 Incident Key  1.000000
# 39                   Report Key  1.000000

# %%
df.shape
# Out:
# (160727, 91)

# %%
print(strong_categorical_correlations)
# Out:
#                          Column   CramerV
# 2               Accident Number  0.947816
# 3                      PDF Link  1.000000
# 6   Maintenance Accident Number  0.943181
# 7                          Date  0.374487
# 9                 Accident Type  0.507784
# 11                      Station  0.487318
# 18                   Track Name  0.460257
# 19                  Track Class  0.234898
# 24                Gross Tonnage  0.323464
# 25           First Car Initials  0.284975
# 26             First Car Number  0.690932
# 28        Equipment Damage Cost  0.543098
# 29            Track Damage Cost  0.367617
# 30            Total Damage Cost  0.640295
# 31  Primary Accident Cause Code  0.498805
# 32       Primary Accident Cause  0.498801
# 33          Accident Cause Code  0.498909
# 34               Accident Cause  0.498905
# 36            Joint Track Class  0.236294
# 38                 Incident Key  1.000000
# 39                   Report Key  1.000000

# %%
df.shape
# Out:
# (160727, 91)

# %%
df.columns
# Out:
# Index(['Accident Number', 'PDF Link', 'Maintenance Accident Number', 'Date',
#        'Accident Type', 'Station', 'Track Name', 'Track Class',
#        'Gross Tonnage', 'First Car Initials', 'First Car Number',
#        'Equipment Damage Cost', 'Track Damage Cost', 'Total Damage Cost',
#        'Primary Accident Cause Code', 'Primary Accident Cause',
#        'Accident Cause Code', 'Accident Cause', 'Joint Track Class',
#        'Incident Key', 'Report Key', 'Accident Type Code', 'Train Speed',
#        'Maximum Speed', 'First Car Position', 'Derailed Head End Locomotives',
#        'Class'],
#       dtype='object')

# %%
# Extract the names of the strongly correlated categorical columns
strong_columns = strong_categorical_correlations['Column']

# Combine the strong categorical columns and the numeric columns to keep
columns_to_include = list(strong_columns) + list(columns_to_keep)

# Create a new dataset with the selected columns
df = df[columns_to_include]

# Display the new dataset
print("New dataset with selected columns:")
print(df.head())
# Out:
# New dataset with selected columns:
#   Accident Number                                           PDF Link  \
# 0        N1700013  https://safetydata.fra.dot.gov/Officeofsafety/...
# 3          543854  https://safetydata.fra.dot.gov/Officeofsafety/...
# 4          938223  https://safetydata.fra.dot.gov/Officeofsafety/...
# 5          127020  https://safetydata.fra.dot.gov/Officeofsafety/...
# 9       CH0417103  https://safetydata.fra.dot.gov/Officeofsafety/...
#
#   Maintenance Accident Number        Date      Accident Type      Station  \
# 0                   201707188    6/6/2017         Derailment      CHICAGO
# 3                    INDUSTRY   1/11/2007         Derailment      RESERVE
# 4                      938223   10/7/2017  Hwy-rail crossing     KANKAKEE
# 5                      127020  10/15/2017         Derailment  BOURBONNAIS
# 9                   CH0417103    4/6/2017         Derailment       CICERO
#
#              Track Name Track Class Gross Tonnage First Car Initials  ...  \
# 0             YARD LEAD         1.0             0               NICD  ...
# 3  #4 SWITCH AT CARGILL         1.0        14,100               CGEX  ...
# 4         HERSCHER SPUR         1.0         3,482               UTLX  ...
# 5                  KA03         1.0         6,706               PROX  ...
# 9                  1108         1.0        15,760               BNSF  ...
#
#   Joint Track Class         Incident Key           Report Key  \
# 0                 1  NIRC201707188201706   NICDN1700013201706
# 3                 1   CAEZINDUSTRY200701       IC543854200701
# 4                 1       IC938223201710       IC938223201710
# 5                 1       NS127020201710       NS127020201710
# 9                 1  BNSFCH0417103201704  BNSFCH0417103201704
#
#   Accident Type Code Track Type Code Train Speed Maximum Speed  \
# 0                1.0             2.0        10.0            10
# 3                1.0             4.0         4.0             4
# 4                7.0             3.0         0.0             0
# 5                1.0             2.0         3.0             3
# 9                1.0             2.0        10.0            10
#
#   First Car Position Derailed Head End Locomotives Class
# 0                2.0                           0.0     0
# 3               70.0                           0.0     0
# 4               40.0                           0.0     1
# 5               58.0                           0.0     0
# 9               41.0                           0.0     0
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (160727, 28)

# %%
df.to_csv('preprocessedDataset.csv', index=False)

# %%
df = pd.read_excel('preprocessedDataset.xlsx')

# %%
df.shape
# Out:
# (160727, 28)

# %%
df.head()
# Out:
#        Station            Track Name Track Class Gross Tonnage  \
# 0      CHICAGO             YARD LEAD           1             0
# 1      RESERVE  #4 SWITCH AT CARGILL           1        14,100
# 2     KANKAKEE         HERSCHER SPUR           1         3,482
# 3  BOURBONNAIS                  KA03           1         6,706
# 4       CICERO                  1108           1        15,760
#
#   Total Damage Cost Primary Accident Cause Code Accident Cause Code  \
# 0           132,013                        T314                T314
# 1             9,986                        T311                T311
# 2            13,231                        M308                M308
# 3           148,289                        H306                H306
# 4            12,146                        E67C                E67C
#
#   Joint Track Class  Accident Type Code  Train Speed  Maximum Speed  Class
# 0                 1                   1           10             10      0
# 1                 1                   1            4              4      0
# 2                 1                   7            0              0      1
# 3                 1                   1            3              3      0
# 4                 1                   1           10             10      0

# %%
print(df.columns)
# Out:
# Index(['Accident Number', 'PDF Link', 'Maintenance Accident Number', 'Date',
#        'Accident Type', 'Station', 'Track Name', 'Track Class',
#        'Gross Tonnage', 'First Car Initials', 'First Car Number',
#        'Equipment Damage Cost', 'Track Damage Cost', 'Total Damage Cost',
#        'Primary Accident Cause Code', 'Primary Accident Cause',
#        'Accident Cause Code', 'Accident Cause', 'Joint Track Class',
#        'Incident Key', 'Report Key', 'Accident Type Code', 'Track Type Code',
#        'Train Speed', 'Maximum Speed', 'First Car Position',
#        'Derailed Head End Locomotives', 'Class'],
#       dtype='object')

# %%
pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.14.0 in e:\anaconda\lib\site-packages (from category_encoders) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in e:\anaconda\lib\site-packages (from category_encoders) (1.4.2)
# Requirement already satisfied: scipy>=1.0.0 in e:\anaconda\lib\site-packages (from category_encoders) (1.13.1)
# Requirement already satisfied: statsmodels>=0.9.0 in e:\anaconda\lib\site-packages (from category_encoders) (0.14.2)
# Requirement already satisfied: pandas>=1.0.5 in e:\anaconda\lib\site-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in e:\anaconda\lib\site-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\anaconda\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\lib\site-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda\lib\site-packages (from pandas>=1.0.5->category_encoders) (2023.3)
# Requirement already satisfied: six in e:\anaconda\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in e:\anaconda\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\anaconda\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in e:\anaconda\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (23.2)
# Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#    ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/81.9 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/81.9 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/81.9 kB ? eta -:--:--
#    --------------- ------------------------ 30.7/81.9 kB 262.6 kB/s eta 0:00:01
#    --------------- ------------------------ 30.7/81.9 kB 262.6 kB/s eta 0:00:01
#    -------------------- ------------------- 41.0/81.9 kB 164.3 kB/s eta 0:00:01
#    ----------------------------------- ---- 71.7/81.9 kB 262.6 kB/s eta 0:00:01
#    ---------------------------------------- 81.9/81.9 kB 286.5 kB/s eta 0:00:00
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.3
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('preprocessedDataset(with 11 columns).csv')

# %%
#encoding categorical variables (11 columns)

# %%
import category_encoders as ce

# Create the target encoder
target_encoder = ce.TargetEncoder(cols=['Station'])

# Fit and transform the 'Station' column based on the target column 'Class'
df['Station_encoded'] = target_encoder.fit_transform(df['Station'], df['Class'])
df =df.drop(columns="Station")

# %%
df.head(2)
# Out:
#    Station            Track Name  Track Class Gross Tonnage  \
# 0  CHICAGO             YARD LEAD            1             0
# 1  RESERVE  #4 SWITCH AT CARGILL            1        14,100
#
#    Joint Track Class  Train Speed  Maximum Speed  Class
# 0                  1           10             10      0
# 1                  1            4              4      0

# %%
# Create the target encoder
target_encoder = ce.TargetEncoder(cols=['Accident Type'])

# Fit and transform the 'Station' column based on the target column 'Class'
df['Accident Type Encoded'] = target_encoder.fit_transform(df['Accident Type'], df['Class'])
df =df.drop(columns="Accident Type")

# %%
df.head(2)
# Out:
#    Track Class Gross Tonnage  Joint Track Class  Train Speed  Maximum Speed  \
# 0            1             0                  1           10             10
# 1            1        14,100                  1            4              4
#
#    Class  Track_Name_encoded  Station_encoded
# 0      0            0.047923         0.053073
# 1      0            0.056953         0.017912

# %%
# Create the target encoder
target_encoder = ce.TargetEncoder(cols=['Track Name'])

# Fit and transform the 'Station' column based on the target column 'Class'
df['Track_Name_encoded'] = target_encoder.fit_transform(df['Track Name'], df['Class'])
df =df.drop(columns="Track Name")

# %%
# Create the target encoder
target_encoder = ce.TargetEncoder(cols=['Accident Cause Code'])

# Fit and transform the 'Station' column based on the target column 'Class'
df['Accident Cause Code encoded'] = target_encoder.fit_transform(df['Accident Cause Code'], df['Class'])
df =df.drop(columns="Accident Cause Code")

# %%
df.shape
# Out:
# (160727, 11)

# %%
df.to_csv('preprocessedDataset(with 11 columns).csv', index=False)

# %%
df = pd.read_csv('preprocessedDataset(with 8 columns)_standarized.csv')

# %%
df = pd.read_csv('preprocessedDataset(with 11 columns).csv')

# %%
df.columns
# Out:
# Index(['Station', 'Track Name', 'Track Class', 'Gross Tonnage',
#        'Joint Track Class', 'Train Speed', 'Maximum Speed', 'Class'],
#       dtype='object')

# %%
#normalizing

# %%
Y = df['Target']
X = df.drop(columns='Target', axis=1)

# %%
Y
# Out:
# 0         0
# 1         0
# 2         1
# 3         0
# 4         0
#          ..
# 160722    0
# 160723    0
# 160724    0
# 160725    0
# 160726    0
# Name: Class, Length: 160727, dtype: int64

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standarized_data = scaler.transform(X)

# %%
X = standarized_data
Y = df['Target']

# %%
type(X)
# Out:
# numpy.ndarray

# %%
type(Y)
# Out:
# pandas.core.series.Series

# %%
X_df = pd.DataFrame(X)
combined_df = pd.concat([X_df, Y.rename('Target')], axis=1)
combined_df.to_csv("preprocessedDataset(with 11 columns)_standarized.csv", index=False)

# %%
X_df = pd.DataFrame(X)
combined_df = pd.concat([X_df, Y.rename('Target')], axis=1)
combined_df.to_csv("preprocessedDataset(with 8 columns)_standarized.csv", index=False)
